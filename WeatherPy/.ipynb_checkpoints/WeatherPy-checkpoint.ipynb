# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f'There is {len(cities)} in the list.')

# # Testing:
# for i in range(len(cities)):
#     if i%50 == 0:
#         print(cities[i])
#     if i == len(cities) - 1:
#         print(cities[i])
        
# print(requests.get(url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&units=metric&q=" + 'rikitea').json())
# Out:
# There is 614 in the list.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
total_set_num = (len(cities) // 50) + 1

city = []
lat = []
lon = []
city = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
failed_counter = 0

url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&units=metric&q="

print('Beginning Data Retrieval')
print('-----------------------------')

for set_counter in range(total_set_num):
    
    try:    

        for record_counter in range(50):

            counter = set_counter * 50 + record_counter
            print(f'Processing Record {record_counter + 1} of Set {set_counter + 1} | {cities[counter]}')
            record_counter += 1

            try:

                query_url = url + cities[counter]
                weather_json = requests.get(query_url, time.sleep(1)).json()

                lat.append(weather_json["coord"]["lat"])
                lon.append(weather_json["coord"]["lon"])
                max_temp.append(weather_json["main"]["temp_max"])
                humidity.append(weather_json["main"]["humidity"])
                cloudiness.append(weather_json["clouds"]["all"])
                wind_speed.append(weather_json["wind"]["speed"])
                country.append(weather_json["sys"]["country"])
                date.append(weather_json["dt"])
                city.append(cities[counter])

            except KeyError:

                print('City not found. Skipping...')
                failed_counter += 1
                
            except:
                
                print('Unexpected Error')
                    
    except IndexError:
        
        break
        

print('-----------------------------')
print(f'There are {failed_counter} cities not found. {len(cities) - failed_counter} cities in dataframe.')
print('Data Retrieval Complete')      
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | buala
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | kavieng
# Processing Record 7 of Set 1 | beyneu
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | tessalit
# Processing Record 10 of Set 1 | cheremukhovo
# Processing Record 11 of Set 1 | garowe
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | haines junction
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | plettenberg bay
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | cap malheureux
# Processing Record 19 of Set 1 | yuma
# Processing Record 20 of Set 1 | itapuranga
# Processing Record 21 of Set 1 | umm jarr
# City not found. Skipping...
# Processing Record 22 of Set 1 | hambantota
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | samana
# Processing Record 25 of Set 1 | nador
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | tupelo
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | seybaplaya
# Processing Record 30 of Set 1 | bengkulu
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | teshie
# Processing Record 33 of Set 1 | laguna
# Processing Record 34 of Set 1 | jutai
# Processing Record 35 of Set 1 | faya
# Processing Record 36 of Set 1 | monrovia
# Processing Record 37 of Set 1 | kankon
# Processing Record 38 of Set 1 | luderitz
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | geraldton
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | bela
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | kahului
# Processing Record 47 of Set 1 | alofi
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | riviere-au-renard
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | constantine
# Processing Record 3 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 2 | taltal
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | yar-sale
# Processing Record 7 of Set 2 | gondanglegi
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | cockburn town
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | collie
# Processing Record 18 of Set 2 | mangan
# Processing Record 19 of Set 2 | mandera
# Processing Record 20 of Set 2 | bubaque
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | augusto correa
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | sinnamary
# Processing Record 25 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | gazanjyk
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | henties bay
# Processing Record 31 of Set 2 | waipawa
# Processing Record 32 of Set 2 | port lincoln
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | awjilah
# Processing Record 35 of Set 2 | athabasca
# Processing Record 36 of Set 2 | dunedin
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | ranikhet
# Processing Record 39 of Set 2 | unye
# City not found. Skipping...
# Processing Record 40 of Set 2 | north branch
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | matamoros
# Processing Record 44 of Set 2 | cotonou
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | saldanha
# Processing Record 47 of Set 2 | hundorp
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | coihaique
# Processing Record 50 of Set 2 | vendas novas
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | dallas
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | knysna
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | hervey bay
# Processing Record 8 of Set 3 | banswada
# Processing Record 9 of Set 3 | nerang
# Processing Record 10 of Set 3 | acapulco
# Processing Record 11 of Set 3 | saint anthony
# Processing Record 12 of Set 3 | necochea
# Processing Record 13 of Set 3 | fortuna
# Processing Record 14 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 3 | egvekinot
# Processing Record 16 of Set 3 | inverell
# Processing Record 17 of Set 3 | san matias
# Processing Record 18 of Set 3 | guerrero negro
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | batagay-alyta
# Processing Record 22 of Set 3 | jiancheng
# Processing Record 23 of Set 3 | lasa
# Processing Record 24 of Set 3 | jumla
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | punta alta
# Processing Record 28 of Set 3 | lagoa
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 31 of Set 3 | zabol
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | novoseleznevo
# Processing Record 34 of Set 3 | qaqortoq
# Processing Record 35 of Set 3 | roswell
# Processing Record 36 of Set 3 | khasan
# Processing Record 37 of Set 3 | whithorn
# Processing Record 38 of Set 3 | olot
# Processing Record 39 of Set 3 | kalaleh
# Processing Record 40 of Set 3 | rumuruti
# Processing Record 41 of Set 3 | beruwala
# Processing Record 42 of Set 3 | nikolskoye
# Processing Record 43 of Set 3 | smithers
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | macusani
# Processing Record 46 of Set 3 | shingu
# Processing Record 47 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 3 | sao felix do xingu
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | taoudenni
# Processing Record 1 of Set 4 | upata
# Processing Record 2 of Set 4 | camocim
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | bandar
# Processing Record 5 of Set 4 | iqaluit
# Processing Record 6 of Set 4 | busselton
# Processing Record 7 of Set 4 | muros
# Processing Record 8 of Set 4 | brae
# Processing Record 9 of Set 4 | gerash
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | brazzaville
# Processing Record 13 of Set 4 | ilulissat
# Processing Record 14 of Set 4 | port augusta
# Processing Record 15 of Set 4 | gigmoto
# Processing Record 16 of Set 4 | bonthe
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | presidente epitacio
# Processing Record 19 of Set 4 | debre sina
# Processing Record 20 of Set 4 | arlit
# Processing Record 21 of Set 4 | kanye
# Processing Record 22 of Set 4 | buraydah
# Processing Record 23 of Set 4 | carnarvon
# Processing Record 24 of Set 4 | svetlogorsk
# Processing Record 25 of Set 4 | birao
# Processing Record 26 of Set 4 | wabana
# Processing Record 27 of Set 4 | yomou
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | norman wells
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 4 | saint george
# Processing Record 33 of Set 4 | palembang
# Processing Record 34 of Set 4 | weston
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | fernandina beach
# Processing Record 37 of Set 4 | vaini
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | ramon
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | zhangye
# Processing Record 42 of Set 4 | nanortalik
# Processing Record 43 of Set 4 | sur
# Processing Record 44 of Set 4 | victoria point
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | novikovo
# Processing Record 47 of Set 4 | tuktoyaktuk
# Processing Record 48 of Set 4 | shubarkuduk
# Processing Record 49 of Set 4 | thinadhoo
# Processing Record 50 of Set 4 | la laguna del pedernal
# City not found. Skipping...
# Processing Record 1 of Set 5 | xichang
# Processing Record 2 of Set 5 | northam
# Processing Record 3 of Set 5 | houma
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | sola
# Processing Record 6 of Set 5 | denizli
# Processing Record 7 of Set 5 | maues
# Processing Record 8 of Set 5 | port elizabeth
# Processing Record 9 of Set 5 | codrington
# Processing Record 10 of Set 5 | ketchikan
# Processing Record 11 of Set 5 | kurumkan
# Processing Record 12 of Set 5 | koungou
# Processing Record 13 of Set 5 | benguela
# Processing Record 14 of Set 5 | venice
# Processing Record 15 of Set 5 | naze
# Processing Record 16 of Set 5 | butaritari
# Processing Record 17 of Set 5 | sulangan
# Processing Record 18 of Set 5 | mundo nuevo
# Processing Record 19 of Set 5 | sobolevo
# Processing Record 20 of Set 5 | timra
# Processing Record 21 of Set 5 | awbari
# Processing Record 22 of Set 5 | wanning
# Processing Record 23 of Set 5 | mozarlandia
# Processing Record 24 of Set 5 | wilmington
# Processing Record 25 of Set 5 | avera
# Processing Record 26 of Set 5 | asau
# Processing Record 27 of Set 5 | leningradskiy
# Processing Record 28 of Set 5 | beringovskiy
# Processing Record 29 of Set 5 | grindavik
# Processing Record 30 of Set 5 | fare
# Processing Record 31 of Set 5 | mar del plata
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | diego de almagro
# Processing Record 34 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 5 | sakti
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | okhotsk
# Processing Record 38 of Set 5 | albion
# Processing Record 39 of Set 5 | saint-paul
# Processing Record 40 of Set 5 | minab
# Processing Record 41 of Set 5 | napoleon
# Processing Record 42 of Set 5 | vila franca do campo
# Processing Record 43 of Set 5 | sobinka
# Processing Record 44 of Set 5 | poum
# Processing Record 45 of Set 5 | buncrana
# Processing Record 46 of Set 5 | college
# Processing Record 47 of Set 5 | catamarca
# Processing Record 48 of Set 5 | ostrovnoy
# Processing Record 49 of Set 5 | siocon
# Processing Record 50 of Set 5 | ulaangom
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | tecolutla
# Processing Record 3 of Set 6 | souillac
# Processing Record 4 of Set 6 | williston
# Processing Record 5 of Set 6 | safaqis
# City not found. Skipping...
# Processing Record 6 of Set 6 | biak
# Processing Record 7 of Set 6 | romanovo
# Processing Record 8 of Set 6 | aklavik
# Processing Record 9 of Set 6 | alpena
# Processing Record 10 of Set 6 | hamilton
# Processing Record 11 of Set 6 | gunjur
# Processing Record 12 of Set 6 | hit
# Processing Record 13 of Set 6 | abu samrah
# Processing Record 14 of Set 6 | tanshui
# City not found. Skipping...
# Processing Record 15 of Set 6 | xining
# Processing Record 16 of Set 6 | meulaboh
# Processing Record 17 of Set 6 | shar
# Processing Record 18 of Set 6 | pangkalanbuun
# Processing Record 19 of Set 6 | constitucion
# Processing Record 20 of Set 6 | talaya
# Processing Record 21 of Set 6 | vezirkopru
# Processing Record 22 of Set 6 | alexandria
# Processing Record 23 of Set 6 | saint-ambroise
# Processing Record 24 of Set 6 | saint-philippe
# Processing Record 25 of Set 6 | padang
# Processing Record 26 of Set 6 | pangnirtung
# Processing Record 27 of Set 6 | port macquarie
# Processing Record 28 of Set 6 | gashua
# Processing Record 29 of Set 6 | gimli
# Processing Record 30 of Set 6 | flin flon
# Processing Record 31 of Set 6 | abu dhabi
# Processing Record 32 of Set 6 | presidencia roque saenz pena
# Processing Record 33 of Set 6 | yulara
# Processing Record 34 of Set 6 | ruteng
# Processing Record 35 of Set 6 | mareeba
# Processing Record 36 of Set 6 | saint-leu
# Processing Record 37 of Set 6 | gizo
# Processing Record 38 of Set 6 | hopkinton
# Processing Record 39 of Set 6 | namatanai
# Processing Record 40 of Set 6 | marathon
# Processing Record 41 of Set 6 | mabaruma
# Processing Record 42 of Set 6 | makriyialos
# City not found. Skipping...
# Processing Record 43 of Set 6 | maceio
# Processing Record 44 of Set 6 | tura
# Processing Record 45 of Set 6 | naduvattam
# Processing Record 46 of Set 6 | clyde river
# Processing Record 47 of Set 6 | beasain
# Processing Record 48 of Set 6 | sidi ali
# Processing Record 49 of Set 6 | rapar
# Processing Record 50 of Set 6 | taksimo
# Processing Record 1 of Set 7 | vitimskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | buchanan
# Processing Record 3 of Set 7 | nouadhibou
# Processing Record 4 of Set 7 | ginir
# Processing Record 5 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 7 | saint-agapit
# Processing Record 7 of Set 7 | nanchang
# Processing Record 8 of Set 7 | vanimo
# Processing Record 9 of Set 7 | bayan
# Processing Record 10 of Set 7 | madhoganj
# Processing Record 11 of Set 7 | nishihara
# Processing Record 12 of Set 7 | kouroussa
# Processing Record 13 of Set 7 | kudahuvadhoo
# Processing Record 14 of Set 7 | kolokani
# Processing Record 15 of Set 7 | urumqi
# Processing Record 16 of Set 7 | bocana de paiwas
# Processing Record 17 of Set 7 | lorengau
# Processing Record 18 of Set 7 | tateyama
# Processing Record 19 of Set 7 | zhigansk
# Processing Record 20 of Set 7 | yarmouth
# Processing Record 21 of Set 7 | bathsheba
# Processing Record 22 of Set 7 | williams lake
# Processing Record 23 of Set 7 | esperance
# Processing Record 24 of Set 7 | tiarei
# Processing Record 25 of Set 7 | hay river
# Processing Record 26 of Set 7 | ovalle
# Processing Record 27 of Set 7 | sabadell
# Processing Record 28 of Set 7 | deniliquin
# Processing Record 29 of Set 7 | darhan
# Processing Record 30 of Set 7 | xinyu
# Processing Record 31 of Set 7 | roebourne
# Processing Record 32 of Set 7 | te anau
# Processing Record 33 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 7 | amapa
# Processing Record 35 of Set 7 | porto walter
# Processing Record 36 of Set 7 | sangar
# Processing Record 37 of Set 7 | santa vitoria
# Processing Record 38 of Set 7 | flinders
# Processing Record 39 of Set 7 | ponta do sol
# Processing Record 40 of Set 7 | half moon bay
# Processing Record 41 of Set 7 | lata
# Processing Record 42 of Set 7 | muli
# Processing Record 43 of Set 7 | kikwit
# Processing Record 44 of Set 7 | anadyr
# Processing Record 45 of Set 7 | broken hill
# Processing Record 46 of Set 7 | port-gentil
# Processing Record 47 of Set 7 | jiayuguan
# Processing Record 48 of Set 7 | omboue
# Processing Record 49 of Set 7 | maniitsoq
# Processing Record 50 of Set 7 | palmer
# Processing Record 1 of Set 8 | lompoc
# Processing Record 2 of Set 8 | micheweni
# Processing Record 3 of Set 8 | ahuatempan
# Processing Record 4 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | touros
# Processing Record 7 of Set 8 | tiznit
# Processing Record 8 of Set 8 | cape coast
# Processing Record 9 of Set 8 | mayo
# Processing Record 10 of Set 8 | indramayu
# Processing Record 11 of Set 8 | homa bay
# Processing Record 12 of Set 8 | nagyoroszi
# Processing Record 13 of Set 8 | kieta
# Processing Record 14 of Set 8 | sinop
# Processing Record 15 of Set 8 | aubenas
# Processing Record 16 of Set 8 | kayes
# Processing Record 17 of Set 8 | hobyo
# Processing Record 18 of Set 8 | piacabucu
# Processing Record 19 of Set 8 | bud
# Processing Record 20 of Set 8 | camacupa
# Processing Record 21 of Set 8 | uddiawan
# Processing Record 22 of Set 8 | goderich
# Processing Record 23 of Set 8 | paamiut
# Processing Record 24 of Set 8 | kushiro
# Processing Record 25 of Set 8 | lavrentiya
# Processing Record 26 of Set 8 | prince rupert
# Processing Record 27 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 8 | cabano
# Processing Record 29 of Set 8 | shakhovskaya
# Processing Record 30 of Set 8 | cuamba
# Processing Record 31 of Set 8 | vyazemskiy
# Processing Record 32 of Set 8 | sergeyevka
# Processing Record 33 of Set 8 | nola
# Processing Record 34 of Set 8 | hazorasp
# Processing Record 35 of Set 8 | kyzyl-suu
# Processing Record 36 of Set 8 | nazarovo
# Processing Record 37 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 8 | beloha
# Processing Record 39 of Set 8 | san andres
# Processing Record 40 of Set 8 | kamaishi
# Processing Record 41 of Set 8 | dudinka
# Processing Record 42 of Set 8 | olafsvik
# Processing Record 43 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 8 | dingle
# Processing Record 45 of Set 8 | xingcheng
# Processing Record 46 of Set 8 | talnakh
# Processing Record 47 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 8 | nevers
# Processing Record 49 of Set 8 | saint-pierre
# Processing Record 50 of Set 8 | leh
# Processing Record 1 of Set 9 | cap-aux-meules
# Processing Record 2 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 9 | sisimiut
# Processing Record 4 of Set 9 | nome
# Processing Record 5 of Set 9 | guaruja
# Processing Record 6 of Set 9 | martapura
# Processing Record 7 of Set 9 | canutama
# Processing Record 8 of Set 9 | manicore
# Processing Record 9 of Set 9 | san francisco
# Processing Record 10 of Set 9 | alice springs
# Processing Record 11 of Set 9 | xiongzhou
# Processing Record 12 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 9 | andenes
# Processing Record 14 of Set 9 | port hedland
# Processing Record 15 of Set 9 | burgeo
# Processing Record 16 of Set 9 | elizabeth city
# Processing Record 17 of Set 9 | khorixas
# Processing Record 18 of Set 9 | eureka
# Processing Record 19 of Set 9 | dunmore east
# Processing Record 20 of Set 9 | imeni poliny osipenko
# Processing Record 21 of Set 9 | port hardy
# Processing Record 22 of Set 9 | rocha
# Processing Record 23 of Set 9 | babushkin
# Processing Record 24 of Set 9 | kandrian
# Processing Record 25 of Set 9 | cidreira
# Processing Record 26 of Set 9 | comodoro rivadavia
# Processing Record 27 of Set 9 | seymchan
# Processing Record 28 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 9 | changping
# Processing Record 30 of Set 9 | dzaoudzi
# Processing Record 31 of Set 9 | fort nelson
# Processing Record 32 of Set 9 | hun
# Processing Record 33 of Set 9 | labrea
# Processing Record 34 of Set 9 | mumford
# Processing Record 35 of Set 9 | camacha
# Processing Record 36 of Set 9 | havre-saint-pierre
# Processing Record 37 of Set 9 | porto novo
# Processing Record 38 of Set 9 | mandalgovi
# Processing Record 39 of Set 9 | gamboma
# Processing Record 40 of Set 9 | vardo
# Processing Record 41 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 9 | caico
# Processing Record 43 of Set 9 | ambon
# Processing Record 44 of Set 9 | manbij
# Processing Record 45 of Set 9 | carutapera
# Processing Record 46 of Set 9 | pasvalys
# Processing Record 47 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 9 | kununurra
# Processing Record 49 of Set 9 | kawardha
# Processing Record 50 of Set 9 | noumea
# Processing Record 1 of Set 10 | stokmarknes
# Processing Record 2 of Set 10 | bonavista
# Processing Record 3 of Set 10 | san patricio
# Processing Record 4 of Set 10 | san luis
# Processing Record 5 of Set 10 | sitka
# Processing Record 6 of Set 10 | casa grande
# Processing Record 7 of Set 10 | sabang
# Processing Record 8 of Set 10 | fort-shevchenko
# Processing Record 9 of Set 10 | sorong
# Processing Record 10 of Set 10 | korla
# Processing Record 11 of Set 10 | college station
# Processing Record 12 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 10 | itarantim
# Processing Record 14 of Set 10 | lively
# Processing Record 15 of Set 10 | vila velha
# Processing Record 16 of Set 10 | obama
# Processing Record 17 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 10 | airai
# Processing Record 19 of Set 10 | mersing
# Processing Record 20 of Set 10 | channel-port aux basques
# Processing Record 21 of Set 10 | mayumba
# Processing Record 22 of Set 10 | chuy
# Processing Record 23 of Set 10 | coari
# Processing Record 24 of Set 10 | broome
# Processing Record 25 of Set 10 | kuandian
# Processing Record 26 of Set 10 | susehri
# Processing Record 27 of Set 10 | kualakapuas
# Processing Record 28 of Set 10 | mehamn
# Processing Record 29 of Set 10 | lander
# Processing Record 30 of Set 10 | caravelas
# Processing Record 31 of Set 10 | thanh hoa
# Processing Record 32 of Set 10 | hede
# Processing Record 33 of Set 10 | roald
# Processing Record 34 of Set 10 | vladimir
# Processing Record 35 of Set 10 | kidal
# Processing Record 36 of Set 10 | manono
# Processing Record 37 of Set 10 | kupino
# Processing Record 38 of Set 10 | cherskiy
# Processing Record 39 of Set 10 | komsomolskiy
# Processing Record 40 of Set 10 | tautira
# Processing Record 41 of Set 10 | labuan
# Processing Record 42 of Set 10 | baykit
# Processing Record 43 of Set 10 | ampanihy
# Processing Record 44 of Set 10 | namibe
# Processing Record 45 of Set 10 | juneau
# Processing Record 46 of Set 10 | natal
# Processing Record 47 of Set 10 | evensk
# Processing Record 48 of Set 10 | sanghar
# Processing Record 49 of Set 10 | senanga
# Processing Record 50 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 11 | xushan
# Processing Record 2 of Set 11 | banda aceh
# Processing Record 3 of Set 11 | vung tau
# Processing Record 4 of Set 11 | hasaki
# Processing Record 5 of Set 11 | el tigre
# Processing Record 6 of Set 11 | klichka
# Processing Record 7 of Set 11 | forestville
# Processing Record 8 of Set 11 | klaksvik
# Processing Record 9 of Set 11 | schwalmstadt
# Processing Record 10 of Set 11 | berlevag
# Processing Record 11 of Set 11 | mount gambier
# Processing Record 12 of Set 11 | clemson
# Processing Record 13 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 14 of Set 11 | balkhash
# Processing Record 15 of Set 11 | muroto
# Processing Record 16 of Set 11 | vuktyl
# Processing Record 17 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 11 | molln
# Processing Record 19 of Set 11 | samastipur
# Processing Record 20 of Set 11 | veraval
# Processing Record 21 of Set 11 | suda
# Processing Record 22 of Set 11 | westport
# Processing Record 23 of Set 11 | itapaci
# Processing Record 24 of Set 11 | mae hong son
# Processing Record 25 of Set 11 | praya
# Processing Record 26 of Set 11 | aswan
# Processing Record 27 of Set 11 | palmerston
# Processing Record 28 of Set 11 | ambilobe
# Processing Record 29 of Set 11 | yatou
# Processing Record 30 of Set 11 | sao joao da barra
# Processing Record 31 of Set 11 | agadez
# Processing Record 32 of Set 11 | anloga
# Processing Record 33 of Set 11 | kapit
# Processing Record 34 of Set 11 | searcy
# Processing Record 35 of Set 11 | kamenka
# Processing Record 36 of Set 11 | jefferson city
# Processing Record 37 of Set 11 | nantucket
# Processing Record 38 of Set 11 | mbanza-ngungu
# Processing Record 39 of Set 11 | novita
# Processing Record 40 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 11 | zwedru
# Processing Record 42 of Set 11 | grahamstown
# Processing Record 43 of Set 11 | lowestoft
# Processing Record 44 of Set 11 | hanko
# Processing Record 45 of Set 11 | jalu
# Processing Record 46 of Set 11 | luanda
# Processing Record 47 of Set 11 | fuente palmera
# Processing Record 48 of Set 11 | darab
# Processing Record 49 of Set 11 | mercedes
# Processing Record 50 of Set 11 | salihorsk
# Processing Record 1 of Set 12 | bulaevo
# Processing Record 2 of Set 12 | sulphur springs
# Processing Record 3 of Set 12 | windham
# Processing Record 4 of Set 12 | przhevalskoye
# Processing Record 5 of Set 12 | jurado
# Processing Record 6 of Set 12 | kabwe
# Processing Record 7 of Set 12 | ahipara
# Processing Record 8 of Set 12 | sevierville
# Processing Record 9 of Set 12 | genhe
# Processing Record 10 of Set 12 | yumen
# Processing Record 11 of Set 12 | santana do matos
# Processing Record 12 of Set 12 | imbituba
# Processing Record 13 of Set 12 | san quintin
# Processing Record 14 of Set 12 | sarahan
# Processing Record 15 of Set 12 | santo antonio do monte
# Processing Record 16 of Set 12 | telsiai
# Processing Record 17 of Set 12 | matara
# Processing Record 18 of Set 12 | bethel
# Processing Record 19 of Set 12 | port-cartier
# Processing Record 20 of Set 12 | beaupre
# Processing Record 21 of Set 12 | nova olimpia
# Processing Record 22 of Set 12 | ulaanbaatar
# Processing Record 23 of Set 12 | robertsport
# Processing Record 24 of Set 12 | lazaro cardenas
# Processing Record 25 of Set 12 | tamworth
# Processing Record 26 of Set 12 | lagoa santa
# Processing Record 27 of Set 12 | marawi
# Processing Record 28 of Set 12 | cayenne
# Processing Record 29 of Set 12 | phumi samraong
# City not found. Skipping...
# Processing Record 30 of Set 12 | svetlaya
# Processing Record 31 of Set 12 | mackay
# Processing Record 32 of Set 12 | albemarle
# Processing Record 33 of Set 12 | balakhta
# Processing Record 34 of Set 12 | san lawrenz
# Processing Record 35 of Set 12 | severodvinsk
# Processing Record 36 of Set 12 | sandane
# Processing Record 37 of Set 12 | tchollire
# Processing Record 38 of Set 12 | dieppe
# Processing Record 39 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 40 of Set 12 | smolenka
# Processing Record 41 of Set 12 | atar
# Processing Record 42 of Set 12 | ekhabi
# Processing Record 43 of Set 12 | sept-iles
# Processing Record 44 of Set 12 | ixtapa
# Processing Record 45 of Set 12 | kalmunai
# Processing Record 46 of Set 12 | ramona
# Processing Record 47 of Set 12 | bam
# Processing Record 48 of Set 12 | saint-augustin
# Processing Record 49 of Set 12 | morro bay
# Processing Record 50 of Set 12 | verkhoyansk
# Processing Record 1 of Set 13 | sao raimundo nonato
# Processing Record 2 of Set 13 | mbandaka
# Processing Record 3 of Set 13 | wanaka
# Processing Record 4 of Set 13 | hami
# Processing Record 5 of Set 13 | ayan
# Processing Record 6 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 13 | ust-nera
# Processing Record 8 of Set 13 | kirensk
# Processing Record 9 of Set 13 | adamovka
# Processing Record 10 of Set 13 | qui nhon
# Processing Record 11 of Set 13 | kemijarvi
# Processing Record 12 of Set 13 | ust-kut
# Processing Record 13 of Set 13 | skoghall
# Processing Record 14 of Set 13 | miles city
# -----------------------------
# There are 47 cities not found. 567 cities in dataframe.
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_dict = {'City': city,
               'Latitude' : lat,
               'Longitude' : lon,
               'Max Temperature (°C)': max_temp,
               'Humidity (%)': humidity,
               'Cloudiness (%)': cloudiness,
               'Wind Speed (MPH)': wind_speed,
               'Country': country,
               'Date': date
              }
cities_df = pd.DataFrame(cities_dict)
csv_path = 'output_data/cities.csv'
cities_df.to_csv(csv_path)
cities_df
# Out:
#            City  Latitude  Longitude  Max Temperature (°C)  Humidity (%)  \
# 0         buala   -8.1450   159.5921                 27.57            77
# 1       ushuaia  -54.8000   -68.3000                  9.00            87
# 2        faanui  -16.4833  -151.7500                 25.69            78
# 3       mataura  -46.1927   168.8643                 17.96            38
# 4        barrow   71.2906  -156.7887                -34.00            85
# ..          ...       ...        ...                   ...           ...
# 562    qui nhon   13.7667   109.2333                 23.56            81
# 563   kemijarvi   66.7131    27.4306                 -6.30            96
# 564     ust-kut   56.7938   105.7672                 -8.37            93
# 565    skoghall   59.3232    13.4655                -11.00            85
# 566  miles city   46.4083  -105.8406                 -8.00            73
#
#      Cloudiness (%)  Wind Speed (MPH) Country        Date
# 0               100              3.26      SB  1612411989
# 1                75              1.54      AR  1612411884
# 2                99              4.49      PF  1612411991
# 3                 0              3.79      NZ  1612411992
# 4                 1              5.66      US  1612411968
# ..              ...               ...     ...         ...
# 562              95              7.52      VN  1612412675
# 563             100              5.37      FI  1612412676
# 564             100              5.67      RU  1612412677
# 565              75              5.14      SE  1612412679
# 566              90              4.63      US  1612412630
#
# [567 rows x 9 columns]

# %%
cities_df.describe()
# Out:
#          Latitude   Longitude  Max Temperature (°C)  Humidity (%)  \
# count  567.000000  567.000000            567.000000    567.000000
# mean    20.633902   15.746110              9.790071     73.940035
# std     32.510202   89.896905             17.231609     19.297831
# min    -54.800000 -179.166700            -41.000000     10.000000
# 25%     -5.224450  -62.770150             -1.000000     65.000000
# 50%     26.326000   16.119400             14.000000     78.000000
# 75%     47.554000   96.249250             24.010000     88.000000
# max     78.218600  179.316700             37.000000    100.000000
#
#        Cloudiness (%)  Wind Speed (MPH)          Date
# count      567.000000        567.000000  5.670000e+02
# mean        50.162257          3.495009  1.612412e+09
# std         40.558231          2.611554  2.055139e+02
# min          0.000000          0.120000  1.612412e+09
# 25%          1.000000          1.540000  1.612412e+09
# 50%         48.000000          2.920000  1.612412e+09
# 75%         92.000000          4.660000  1.612412e+09
# max        100.000000         14.630000  1.612413e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cleaned_cities_df = cities_df.loc[cities_df['Humidity (%)'] <= 100]
cleaned_cities_df
# Out:
#            City  Latitude  Longitude  Max Temperature (°C)  Humidity (%)  \
# 0         buala   -8.1450   159.5921                 27.57            77
# 1       ushuaia  -54.8000   -68.3000                  9.00            87
# 2        faanui  -16.4833  -151.7500                 25.69            78
# 3       mataura  -46.1927   168.8643                 17.96            38
# 4        barrow   71.2906  -156.7887                -34.00            85
# ..          ...       ...        ...                   ...           ...
# 562    qui nhon   13.7667   109.2333                 23.56            81
# 563   kemijarvi   66.7131    27.4306                 -6.30            96
# 564     ust-kut   56.7938   105.7672                 -8.37            93
# 565    skoghall   59.3232    13.4655                -11.00            85
# 566  miles city   46.4083  -105.8406                 -8.00            73
#
#      Cloudiness (%)  Wind Speed (MPH) Country        Date
# 0               100              3.26      SB  1612411989
# 1                75              1.54      AR  1612411884
# 2                99              4.49      PF  1612411991
# 3                 0              3.79      NZ  1612411992
# 4                 1              5.66      US  1612411968
# ..              ...               ...     ...         ...
# 562              95              7.52      VN  1612412675
# 563             100              5.37      FI  1612412676
# 564             100              5.67      RU  1612412677
# 565              75              5.14      SE  1612412679
# 566              90              4.63      US  1612412630
#
# [567 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
cleaned_cities_df.plot(kind='scatter', x='Latitude', y='Max Temperature (°C)', title='Latitude vs. Max Temperature')
plt.grid()
plt.savefig('output_data/Latitude_MaxTemperature_Plot.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
cleaned_cities_df.plot(kind='scatter', x='Latitude', y='Humidity (%)', title='Latitude vs. Humidity')
plt.grid()
plt.savefig('output_data/Latitude_Humidity_Plot.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cleaned_cities_df.plot(kind='scatter', x='Latitude', y='Cloudiness (%)', title='Latitude vs. Cloudiness')
plt.grid()
plt.savefig('output_data/Latitude_Cloudiness_Plot.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
cleaned_cities_df.plot(kind='scatter', x='Latitude', y='Wind Speed (MPH)', title='Latitude vs. Wind Speed')
plt.grid()
plt.savefig('output_data/Latitude_WindSpeed_Plot.png')

# %% [markdown]
# ## Linear Regression

# %%
north_cities_df = cleaned_cities_df.loc[cleaned_cities_df['Latitude'] >= 0]
south_cities_df = cleaned_cities_df.loc[cleaned_cities_df['Latitude'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_cities_df.plot(kind='scatter', x='Latitude', y='Max Temperature (°C)', title='Latitude vs. Max Temperature')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_df['Latitude'], north_cities_df['Max Temperature (°C)'])
regress_values = north_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_cities_df['Latitude'], north_cities_df['Max Temperature (°C)'])
plt.plot(north_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq, (45, 30),fontsize=14,color="red")

print(f'The r-value is {rvalue}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-value is -0.8791168489079155
# The linear regression model is y = -0.76x + 33.15

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_cities_df.plot(kind='scatter', x='Latitude', y='Max Temperature (°C)', title='Latitude vs. Max Temperature')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_df['Latitude'], south_cities_df['Max Temperature (°C)'])
regress_values = south_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_cities_df['Latitude'], south_cities_df['Max Temperature (°C)'])
plt.plot(south_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(-55,35),fontsize=14,color="red")

print(f'The r-value is {rvalue}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-value is 0.4634455174725618
# The linear regression model is y = 0.18x + 27.4

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_cities_df.plot(kind='scatter', x='Latitude', y='Humidity (%)', title='Latitude vs. Humidity')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_df['Latitude'], north_cities_df['Humidity (%)'])
regress_values = north_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_cities_df['Latitude'], north_cities_df['Humidity (%)'])
plt.plot(north_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(46,13),fontsize=14,color="red")

print(f'The r-value is {rvalue}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-value is 0.2936096566588897
# The linear regression model is y = 0.29x + 62.26

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_cities_df.plot(kind='scatter', x='Latitude', y='Humidity (%)', title='Latitude vs. Humidity')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_df['Latitude'], south_cities_df['Humidity (%)'])
regress_values = south_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_cities_df['Latitude'], south_cities_df['Humidity (%)'])
plt.plot(south_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(-22,18),fontsize=14,color="red")

print(f'The r-value is {rvalue}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-value is 0.32215366119344324
# The linear regression model is y = 0.44x + 83.87

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_cities_df.plot(kind='scatter', x='Latitude', y='Cloudiness (%)', title='Latitude vs. Cloudiness')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_df['Latitude'], north_cities_df['Cloudiness (%)'])
regress_values = north_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_cities_df['Latitude'], north_cities_df['Cloudiness (%)'])
plt.plot(north_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(25,23.5),fontsize=14,color="red")

print(f'The r-value is {rvalue}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-value is 0.20827224549353004
# The linear regression model is y = 0.43x + 33.24

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_cities_df.plot(kind='scatter', x='Latitude', y='Cloudiness (%)', title='Latitude vs. Cloudiness')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_df['Latitude'], south_cities_df['Cloudiness (%)'])
regress_values = south_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_cities_df['Latitude'], south_cities_df['Cloudiness (%)'])
plt.plot(south_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(-56,80),fontsize=14,color="red")

print(f'The r-value is {rvalue}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-value is 0.3611585307325017
# The linear regression model is y = 1.07x + 72.56

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_cities_df.plot(kind='scatter', x='Latitude', y='Wind Speed (MPH)', title='Latitude vs. Wind Speed')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_df['Latitude'], north_cities_df['Wind Speed (MPH)'])
regress_values = north_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_cities_df['Latitude'], north_cities_df['Wind Speed (MPH)'])
plt.plot(north_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(0,14),fontsize=14,color="red")

print(f'The r-value is {rvalue}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-value is 0.10233508958999171
# The linear regression model is y = 0.01x + 3.07

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_cities_df.plot(kind='scatter', x='Latitude', y='Wind Speed (MPH)', title='Latitude vs. Wind Speed')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_df['Latitude'], south_cities_df['Wind Speed (MPH)'])
regress_values = south_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_cities_df['Latitude'], south_cities_df['Wind Speed (MPH)'])
plt.plot(south_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(-55,12.5),fontsize=14,color="red")

print(f'The r-value is {rvalue}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-value is -0.2300570468459737
# The linear regression model is y = -0.04x + 2.38
