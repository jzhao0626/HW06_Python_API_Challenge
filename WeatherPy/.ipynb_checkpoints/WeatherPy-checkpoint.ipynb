# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Incorportaed datetime to determine the date of analysis
import datetime
today = datetime.date.today()

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f'There is {len(cities)} in the list.')

# # Testing:
# for i in range(len(cities)):
#     if i%50 == 0:
#         print(cities[i])
#     if i == len(cities) - 1:
#         print(cities[i])
        
# print(requests.get(url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&units=metric&q=" + 'rikitea').json())
# Out:
# There is 620 in the list.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Get the number of sets needed in the for loop
total_set_num = (len(cities) // 50) + 1

# Set up the lists which will be used to create dataframe
city = []
lat = []
lon = []
city = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
failed_counter = 0
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&units=metric&q="

# Start to extracting cities' weather info
print('Beginning Data Retrieval')
print('-----------------------------')

for set_counter in range(total_set_num):
    
    # Use try and except block to prevent the code from stopping when the set does not have 50 records
    try:    
        
        # For each record, use openweather API to get access to all the information and append to corresponding lists
        for record_counter in range(50):
            
            # The counter represent the actual index the city is in the cities list 
            counter = set_counter * 50 + record_counter
            
            # Print the current set and record index
            print(f'Processing Record {record_counter + 1} of Set {set_counter + 1} | {cities[counter]}')

            # Use try and except block to prevent the code from stopping when a city cannot be found
            try:
                
                # Get the query url and make a call
                query_url = url + cities[counter]
                weather_json = requests.get(query_url, time.sleep(1)).json()
                
                # Append to lists
                lat.append(weather_json["coord"]["lat"])
                lon.append(weather_json["coord"]["lon"])
                max_temp.append(weather_json["main"]["temp_max"])
                humidity.append(weather_json["main"]["humidity"])
                cloudiness.append(weather_json["clouds"]["all"])
                wind_speed.append(weather_json["wind"]["speed"])
                country.append(weather_json["sys"]["country"])
                date.append(weather_json["dt"])
                city.append(cities[counter])
            
            # If city not found, print it out, and increment to the failed counter
            except KeyError:

                print('City not found. Skipping...')
                failed_counter += 1
            
            # (For testing)If any other error, print it out
            except:
                
                print('Unexpected Error')
    
    # Break out from the loop once the IndexError was found
    except IndexError:
        
        break
        
# Print out the number of cities found and not found
print('-----------------------------')
print(f'There are {failed_counter} cities not found. {len(cities) - failed_counter} cities in dataframe.')
print('Data Retrieval Complete')      
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | bubaque
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | kavaratti
# Processing Record 8 of Set 1 | caravelas
# Processing Record 9 of Set 1 | sola
# Processing Record 10 of Set 1 | port hardy
# Processing Record 11 of Set 1 | araouane
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | vao
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | montevideo
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | bakov nad jizerou
# Processing Record 23 of Set 1 | korhogo
# Processing Record 24 of Set 1 | huarmey
# Processing Record 25 of Set 1 | ambon
# Processing Record 26 of Set 1 | pisco
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | port lincoln
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | thinadhoo
# Processing Record 31 of Set 1 | saint-pierre
# Processing Record 32 of Set 1 | tilichiki
# Processing Record 33 of Set 1 | port macquarie
# Processing Record 34 of Set 1 | yulin
# Processing Record 35 of Set 1 | solnechnyy
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | grand gaube
# Processing Record 38 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 39 of Set 1 | berlevag
# Processing Record 40 of Set 1 | saint anthony
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | yumen
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | nouadhibou
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | mabaruma
# Processing Record 49 of Set 1 | los llanos de aridane
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | yara
# Processing Record 2 of Set 2 | fort nelson
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | hamilton
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | pochutla
# Processing Record 9 of Set 2 | trairi
# Processing Record 10 of Set 2 | gweru
# Processing Record 11 of Set 2 | vostok
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | the valley
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | kieta
# Processing Record 20 of Set 2 | nemuro
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 2 | belyy yar
# Processing Record 26 of Set 2 | januaria
# Processing Record 27 of Set 2 | souillac
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | hami
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | guerrero negro
# Processing Record 32 of Set 2 | aklavik
# Processing Record 33 of Set 2 | nome
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | ucluelet
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | bathsheba
# Processing Record 39 of Set 2 | faanui
# Processing Record 40 of Set 2 | north bend
# Processing Record 41 of Set 2 | makakilo city
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | doha
# Processing Record 46 of Set 2 | hofn
# Processing Record 47 of Set 2 | tautira
# Processing Record 48 of Set 2 | kruisfontein
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | kahului
# Processing Record 1 of Set 3 | plast
# Processing Record 2 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 3 | dickinson
# Processing Record 4 of Set 3 | santa ana
# Processing Record 5 of Set 3 | adre
# Processing Record 6 of Set 3 | new norfolk
# Processing Record 7 of Set 3 | tunceli
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | leh
# Processing Record 10 of Set 3 | qaqortoq
# Processing Record 11 of Set 3 | killybegs
# Processing Record 12 of Set 3 | sao joao da barra
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 3 | tuban
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | moerai
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 3 | vestmannaeyjar
# Processing Record 22 of Set 3 | charters towers
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | chirongui
# Processing Record 25 of Set 3 | bandarbeyla
# Processing Record 26 of Set 3 | ghanzi
# Processing Record 27 of Set 3 | peshkopi
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | hirado
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | gorin
# Processing Record 32 of Set 3 | marawi
# Processing Record 33 of Set 3 | murgab
# Processing Record 34 of Set 3 | kloulklubed
# Processing Record 35 of Set 3 | lata
# Processing Record 36 of Set 3 | kaeo
# Processing Record 37 of Set 3 | mecca
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | soubre
# Processing Record 40 of Set 3 | airai
# Processing Record 41 of Set 3 | lorengau
# Processing Record 42 of Set 3 | blenheim
# Processing Record 43 of Set 3 | smithers
# Processing Record 44 of Set 3 | yellowknife
# Processing Record 45 of Set 3 | vuktyl
# Processing Record 46 of Set 3 | almansa
# Processing Record 47 of Set 3 | rockland
# Processing Record 48 of Set 3 | luebo
# Processing Record 49 of Set 3 | beringovskiy
# Processing Record 50 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | uri
# Processing Record 2 of Set 4 | sergeyevka
# Processing Record 3 of Set 4 | mezen
# Processing Record 4 of Set 4 | ilo
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | manyana
# Processing Record 7 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 4 | mount isa
# Processing Record 9 of Set 4 | shingu
# Processing Record 10 of Set 4 | strezhevoy
# Processing Record 11 of Set 4 | passo de camaragibe
# Processing Record 12 of Set 4 | pangnirtung
# Processing Record 13 of Set 4 | shache
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | kingston
# Processing Record 16 of Set 4 | vung tau
# Processing Record 17 of Set 4 | sisimiut
# Processing Record 18 of Set 4 | imeni poliny osipenko
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | uroteppa
# City not found. Skipping...
# Processing Record 21 of Set 4 | ixtapa
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | christchurch
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | kabare
# Processing Record 26 of Set 4 | bitung
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | trincomalee
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | saldanha
# Processing Record 33 of Set 4 | monrovia
# Processing Record 34 of Set 4 | taraz
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | mehamn
# Processing Record 37 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 4 | bagdarin
# Processing Record 39 of Set 4 | russell
# Processing Record 40 of Set 4 | cockburn town
# Processing Record 41 of Set 4 | sussex
# Processing Record 42 of Set 4 | banda aceh
# Processing Record 43 of Set 4 | oktyabrskiy
# Processing Record 44 of Set 4 | ponta do sol
# Processing Record 45 of Set 4 | constitucion
# Processing Record 46 of Set 4 | sioux lookout
# Processing Record 47 of Set 4 | comodoro rivadavia
# Processing Record 48 of Set 4 | arraial do cabo
# Processing Record 49 of Set 4 | osoyoos
# Processing Record 50 of Set 4 | ternate
# Processing Record 1 of Set 5 | aswan
# Processing Record 2 of Set 5 | mayo
# Processing Record 3 of Set 5 | fomboni
# Processing Record 4 of Set 5 | mahebourg
# Processing Record 5 of Set 5 | toppenish
# Processing Record 6 of Set 5 | boa vista
# Processing Record 7 of Set 5 | gillette
# Processing Record 8 of Set 5 | nioro
# Processing Record 9 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 5 | kudahuvadhoo
# Processing Record 11 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | kabanjahe
# Processing Record 13 of Set 5 | lagoa vermelha
# Processing Record 14 of Set 5 | haines junction
# Processing Record 15 of Set 5 | qazvin
# Processing Record 16 of Set 5 | norfolk
# Processing Record 17 of Set 5 | cherskiy
# Processing Record 18 of Set 5 | yulara
# Processing Record 19 of Set 5 | ongandjera
# Processing Record 20 of Set 5 | trinidad
# Processing Record 21 of Set 5 | govindgarh
# Processing Record 22 of Set 5 | gimli
# Processing Record 23 of Set 5 | ottawa
# Processing Record 24 of Set 5 | chuy
# Processing Record 25 of Set 5 | itambacuri
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 5 | tevaitoa
# Processing Record 29 of Set 5 | mopipi
# Processing Record 30 of Set 5 | aykhal
# Processing Record 31 of Set 5 | biak
# Processing Record 32 of Set 5 | acapulco
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | grand-santi
# Processing Record 35 of Set 5 | klamath falls
# Processing Record 36 of Set 5 | nueva loja
# Processing Record 37 of Set 5 | burgeo
# Processing Record 38 of Set 5 | ashland
# Processing Record 39 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | tiksi
# Processing Record 41 of Set 5 | norton
# Processing Record 42 of Set 5 | kamaishi
# Processing Record 43 of Set 5 | clearwater
# Processing Record 44 of Set 5 | were ilu
# Processing Record 45 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 5 | san quintin
# Processing Record 47 of Set 5 | coquimbo
# Processing Record 48 of Set 5 | bury saint edmunds
# City not found. Skipping...
# Processing Record 49 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 5 | kimbe
# Processing Record 1 of Set 6 | mumford
# Processing Record 2 of Set 6 | nelson bay
# Processing Record 3 of Set 6 | flin flon
# Processing Record 4 of Set 6 | omboue
# Processing Record 5 of Set 6 | rawson
# Processing Record 6 of Set 6 | wer
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | semporna
# Processing Record 9 of Set 6 | juneau
# Processing Record 10 of Set 6 | okmulgee
# Processing Record 11 of Set 6 | sorong
# Processing Record 12 of Set 6 | svetlaya
# Processing Record 13 of Set 6 | tongchuan
# Processing Record 14 of Set 6 | vanimo
# Processing Record 15 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 6 | mantua
# Processing Record 17 of Set 6 | khristoforovo
# City not found. Skipping...
# Processing Record 18 of Set 6 | mandello del lario
# Processing Record 19 of Set 6 | doka
# Processing Record 20 of Set 6 | husavik
# Processing Record 21 of Set 6 | olafsvik
# Processing Record 22 of Set 6 | acarau
# Processing Record 23 of Set 6 | odweyne
# Processing Record 24 of Set 6 | mount gambier
# Processing Record 25 of Set 6 | cape canaveral
# Processing Record 26 of Set 6 | sept-iles
# Processing Record 27 of Set 6 | saint george
# Processing Record 28 of Set 6 | manuel doblado
# City not found. Skipping...
# Processing Record 29 of Set 6 | rorvik
# Processing Record 30 of Set 6 | deputatskiy
# Processing Record 31 of Set 6 | teyateyaneng
# Processing Record 32 of Set 6 | rio gallegos
# Processing Record 33 of Set 6 | lapas
# Processing Record 34 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 6 | noyabrsk
# Processing Record 36 of Set 6 | zhanaozen
# Processing Record 37 of Set 6 | honningsvag
# Processing Record 38 of Set 6 | lishui
# Processing Record 39 of Set 6 | ketchikan
# Processing Record 40 of Set 6 | akdepe
# Processing Record 41 of Set 6 | yenagoa
# Processing Record 42 of Set 6 | verkhnyaya inta
# Processing Record 43 of Set 6 | tharad
# Processing Record 44 of Set 6 | lewistown
# Processing Record 45 of Set 6 | bereda
# Processing Record 46 of Set 6 | korla
# Processing Record 47 of Set 6 | belmonte
# Processing Record 48 of Set 6 | iqaluit
# Processing Record 49 of Set 6 | salalah
# Processing Record 50 of Set 6 | esmeraldas
# Processing Record 1 of Set 7 | adrar
# Processing Record 2 of Set 7 | angoche
# Processing Record 3 of Set 7 | lagoa
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | chifeng
# Processing Record 6 of Set 7 | meadow lake
# Processing Record 7 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 7 | baykit
# Processing Record 9 of Set 7 | carnot
# Processing Record 10 of Set 7 | port blair
# Processing Record 11 of Set 7 | puerto colombia
# Processing Record 12 of Set 7 | kodiak
# Processing Record 13 of Set 7 | flinders
# Processing Record 14 of Set 7 | taltal
# Processing Record 15 of Set 7 | rocha
# Processing Record 16 of Set 7 | talnakh
# Processing Record 17 of Set 7 | chokurdakh
# Processing Record 18 of Set 7 | kidderminster
# Processing Record 19 of Set 7 | murygino
# Processing Record 20 of Set 7 | alexandria
# Processing Record 21 of Set 7 | goure
# Processing Record 22 of Set 7 | waingapu
# Processing Record 23 of Set 7 | rogun
# City not found. Skipping...
# Processing Record 24 of Set 7 | raymond
# Processing Record 25 of Set 7 | sinnamary
# Processing Record 26 of Set 7 | hai phong
# City not found. Skipping...
# Processing Record 27 of Set 7 | ancud
# Processing Record 28 of Set 7 | menongue
# Processing Record 29 of Set 7 | bukachacha
# Processing Record 30 of Set 7 | newala
# Processing Record 31 of Set 7 | meiktila
# Processing Record 32 of Set 7 | anajatuba
# Processing Record 33 of Set 7 | tecoanapa
# Processing Record 34 of Set 7 | pemba
# Processing Record 35 of Set 7 | bilma
# Processing Record 36 of Set 7 | harare
# Processing Record 37 of Set 7 | boende
# Processing Record 38 of Set 7 | slavyanka
# Processing Record 39 of Set 7 | pacific grove
# Processing Record 40 of Set 7 | udachnyy
# Processing Record 41 of Set 7 | yerbogachen
# Processing Record 42 of Set 7 | caconda
# Processing Record 43 of Set 7 | sao joao nepomuceno
# Processing Record 44 of Set 7 | kuznechikha
# Processing Record 45 of Set 7 | bilibino
# Processing Record 46 of Set 7 | aksay
# Processing Record 47 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 48 of Set 7 | la union
# Processing Record 49 of Set 7 | omsukchan
# Processing Record 50 of Set 7 | iracoubo
# Processing Record 1 of Set 8 | upernavik
# Processing Record 2 of Set 8 | xam nua
# Processing Record 3 of Set 8 | portland
# Processing Record 4 of Set 8 | high level
# Processing Record 5 of Set 8 | ramhormoz
# Processing Record 6 of Set 8 | jiaxing
# Processing Record 7 of Set 8 | prince rupert
# Processing Record 8 of Set 8 | lakheri
# Processing Record 9 of Set 8 | cayenne
# Processing Record 10 of Set 8 | baiyin
# Processing Record 11 of Set 8 | tasiilaq
# Processing Record 12 of Set 8 | bazarnyye mataki
# Processing Record 13 of Set 8 | anori
# Processing Record 14 of Set 8 | umm lajj
# Processing Record 15 of Set 8 | ponta delgada
# Processing Record 16 of Set 8 | nanuque
# Processing Record 17 of Set 8 | esperance
# Processing Record 18 of Set 8 | alakurtti
# Processing Record 19 of Set 8 | gazanjyk
# Processing Record 20 of Set 8 | osakarovka
# Processing Record 21 of Set 8 | abha
# Processing Record 22 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 8 | dingle
# Processing Record 24 of Set 8 | sorland
# Processing Record 25 of Set 8 | north port
# Processing Record 26 of Set 8 | kuala terengganu
# Processing Record 27 of Set 8 | ouesso
# Processing Record 28 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 8 | bol
# Processing Record 30 of Set 8 | onega
# Processing Record 31 of Set 8 | papara
# Processing Record 32 of Set 8 | emba
# Processing Record 33 of Set 8 | mareeba
# Processing Record 34 of Set 8 | upington
# Processing Record 35 of Set 8 | bahia blanca
# Processing Record 36 of Set 8 | katsuura
# Processing Record 37 of Set 8 | hohhot
# Processing Record 38 of Set 8 | oranjemund
# Processing Record 39 of Set 8 | yantal
# Processing Record 40 of Set 8 | sobolevo
# Processing Record 41 of Set 8 | paita
# Processing Record 42 of Set 8 | troitskoye
# Processing Record 43 of Set 8 | nong khai
# Processing Record 44 of Set 8 | san vicente
# Processing Record 45 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 46 of Set 8 | ahipara
# Processing Record 47 of Set 8 | queimadas
# Processing Record 48 of Set 8 | senneterre
# Processing Record 49 of Set 8 | san carlos del zulia
# Processing Record 50 of Set 8 | bull savanna
# Processing Record 1 of Set 9 | tall kayf
# Processing Record 2 of Set 9 | kachiry
# Processing Record 3 of Set 9 | morondava
# Processing Record 4 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 9 | general roca
# Processing Record 6 of Set 9 | kavieng
# Processing Record 7 of Set 9 | uyuni
# Processing Record 8 of Set 9 | verkhnevilyuysk
# Processing Record 9 of Set 9 | daru
# Processing Record 10 of Set 9 | tambacounda
# Processing Record 11 of Set 9 | harper
# Processing Record 12 of Set 9 | san juan de los morros
# Processing Record 13 of Set 9 | erzin
# Processing Record 14 of Set 9 | soe
# Processing Record 15 of Set 9 | lubbock
# Processing Record 16 of Set 9 | shelburne
# Processing Record 17 of Set 9 | yongan
# Processing Record 18 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 9 | lixourion
# Processing Record 20 of Set 9 | quelimane
# Processing Record 21 of Set 9 | taywarah
# Processing Record 22 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 9 | nishihara
# Processing Record 24 of Set 9 | oxapampa
# Processing Record 25 of Set 9 | santiago
# Processing Record 26 of Set 9 | maputo
# Processing Record 27 of Set 9 | nabire
# Processing Record 28 of Set 9 | tuatapere
# Processing Record 29 of Set 9 | bakaly
# Processing Record 30 of Set 9 | ojinaga
# Processing Record 31 of Set 9 | yabrud
# Processing Record 32 of Set 9 | rodrigues alves
# Processing Record 33 of Set 9 | neiafu
# Processing Record 34 of Set 9 | sanming
# Processing Record 35 of Set 9 | bhuvanagiri
# Processing Record 36 of Set 9 | jalingo
# Processing Record 37 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 9 | vinh
# Processing Record 39 of Set 9 | ruwi
# Processing Record 40 of Set 9 | mananara
# Processing Record 41 of Set 9 | tezu
# Processing Record 42 of Set 9 | malegaon
# Processing Record 43 of Set 9 | port moresby
# Processing Record 44 of Set 9 | lavrentiya
# Processing Record 45 of Set 9 | cabo san lucas
# Processing Record 46 of Set 9 | laguna
# Processing Record 47 of Set 9 | yar-sale
# Processing Record 48 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 9 | copiapo
# Processing Record 50 of Set 9 | huntington
# Processing Record 1 of Set 10 | chimoio
# Processing Record 2 of Set 10 | dalbandin
# Processing Record 3 of Set 10 | iseyin
# Processing Record 4 of Set 10 | romny
# Processing Record 5 of Set 10 | fort smith
# Processing Record 6 of Set 10 | dukat
# Processing Record 7 of Set 10 | ferrol
# Processing Record 8 of Set 10 | porosozero
# Processing Record 9 of Set 10 | santa cruz
# Processing Record 10 of Set 10 | serebryanyy bor
# Processing Record 11 of Set 10 | san carlos de bariloche
# Processing Record 12 of Set 10 | west bay
# Processing Record 13 of Set 10 | gari
# Processing Record 14 of Set 10 | pala
# Processing Record 15 of Set 10 | bronnoysund
# Processing Record 16 of Set 10 | kamiiso
# Processing Record 17 of Set 10 | jalu
# Processing Record 18 of Set 10 | ayr
# Processing Record 19 of Set 10 | vila franca do campo
# Processing Record 20 of Set 10 | norrtalje
# Processing Record 21 of Set 10 | goderich
# Processing Record 22 of Set 10 | luderitz
# Processing Record 23 of Set 10 | treinta y tres
# Processing Record 24 of Set 10 | muskegon
# Processing Record 25 of Set 10 | geraldton
# Processing Record 26 of Set 10 | algiers
# Processing Record 27 of Set 10 | sucevita
# Processing Record 28 of Set 10 | dunedin
# Processing Record 29 of Set 10 | hereford
# Processing Record 30 of Set 10 | san juan
# Processing Record 31 of Set 10 | saint-gilles
# Processing Record 32 of Set 10 | hobyo
# Processing Record 33 of Set 10 | tarbagatay
# Processing Record 34 of Set 10 | kununurra
# Processing Record 35 of Set 10 | eyl
# Processing Record 36 of Set 10 | meulaboh
# Processing Record 37 of Set 10 | zhigansk
# Processing Record 38 of Set 10 | kuruman
# Processing Record 39 of Set 10 | ajdabiya
# Processing Record 40 of Set 10 | chunan
# Processing Record 41 of Set 10 | maldonado
# Processing Record 42 of Set 10 | hasaki
# Processing Record 43 of Set 10 | sechura
# Processing Record 44 of Set 10 | matara
# Processing Record 45 of Set 10 | mersing
# Processing Record 46 of Set 10 | celestun
# Processing Record 47 of Set 10 | port keats
# Processing Record 48 of Set 10 | jumla
# Processing Record 49 of Set 10 | arenal
# Processing Record 50 of Set 10 | ural
# Processing Record 1 of Set 11 | narrabri
# Processing Record 2 of Set 11 | forio
# Processing Record 3 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 11 | viedma
# Processing Record 5 of Set 11 | neyshabur
# Processing Record 6 of Set 11 | walvis bay
# Processing Record 7 of Set 11 | kiama
# Processing Record 8 of Set 11 | tazovskiy
# Processing Record 9 of Set 11 | mangai
# Processing Record 10 of Set 11 | lubao
# Processing Record 11 of Set 11 | cermik
# Processing Record 12 of Set 11 | miraflores
# Processing Record 13 of Set 11 | visby
# Processing Record 14 of Set 11 | impfondo
# Processing Record 15 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 11 | necochea
# Processing Record 17 of Set 11 | pag
# Processing Record 18 of Set 11 | la ronge
# Processing Record 19 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 20 of Set 11 | montes altos
# Processing Record 21 of Set 11 | aljezur
# Processing Record 22 of Set 11 | gornyy
# Processing Record 23 of Set 11 | garowe
# Processing Record 24 of Set 11 | norman wells
# Processing Record 25 of Set 11 | kalmar
# Processing Record 26 of Set 11 | tommot
# Processing Record 27 of Set 11 | konevo
# Processing Record 28 of Set 11 | sao paulo de olivenca
# Processing Record 29 of Set 11 | progreso
# Processing Record 30 of Set 11 | erdenet
# Processing Record 31 of Set 11 | kupino
# Processing Record 32 of Set 11 | gurupi
# Processing Record 33 of Set 11 | karwar
# Processing Record 34 of Set 11 | college
# Processing Record 35 of Set 11 | kalawit
# Processing Record 36 of Set 11 | bangkal
# Processing Record 37 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 11 | bay roberts
# Processing Record 39 of Set 11 | ritchie
# Processing Record 40 of Set 11 | basco
# Processing Record 41 of Set 11 | vangaindrano
# Processing Record 42 of Set 11 | mus
# Processing Record 43 of Set 11 | camacha
# Processing Record 44 of Set 11 | shenzhen
# Processing Record 45 of Set 11 | santa cruz do capibaribe
# Processing Record 46 of Set 11 | marzuq
# Processing Record 47 of Set 11 | palasa
# Processing Record 48 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 11 | ibra
# Processing Record 50 of Set 11 | san patricio
# Processing Record 1 of Set 12 | pemagatsel
# Processing Record 2 of Set 12 | fukuma
# Processing Record 3 of Set 12 | tottori
# Processing Record 4 of Set 12 | jardim
# Processing Record 5 of Set 12 | sao francisco
# Processing Record 6 of Set 12 | muisne
# Processing Record 7 of Set 12 | eureka
# Processing Record 8 of Set 12 | powell river
# Processing Record 9 of Set 12 | panzhihua
# Processing Record 10 of Set 12 | olinda
# Processing Record 11 of Set 12 | umba
# Processing Record 12 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 12 | krasnoselkup
# Processing Record 14 of Set 12 | komsomolskiy
# Processing Record 15 of Set 12 | eregli
# Processing Record 16 of Set 12 | beboto
# Processing Record 17 of Set 12 | huilong
# Processing Record 18 of Set 12 | karratha
# Processing Record 19 of Set 12 | vicuna
# Processing Record 20 of Set 12 | skjervoy
# Processing Record 21 of Set 12 | lasa
# Processing Record 22 of Set 12 | dehui
# Processing Record 23 of Set 12 | boquira
# Processing Record 24 of Set 12 | collie
# Processing Record 25 of Set 12 | ust-omchug
# Processing Record 26 of Set 12 | gao
# Processing Record 27 of Set 12 | bonthe
# Processing Record 28 of Set 12 | northam
# Processing Record 29 of Set 12 | gurdaspur
# City not found. Skipping...
# Processing Record 30 of Set 12 | kuminskiy
# Processing Record 31 of Set 12 | owando
# Processing Record 32 of Set 12 | broken hill
# Processing Record 33 of Set 12 | honiara
# Processing Record 34 of Set 12 | gravelbourg
# Processing Record 35 of Set 12 | amapa
# Processing Record 36 of Set 12 | lubumbashi
# Processing Record 37 of Set 12 | rawlins
# Processing Record 38 of Set 12 | hope
# Processing Record 39 of Set 12 | rio grande
# Processing Record 40 of Set 12 | tiznit
# Processing Record 41 of Set 12 | halifax
# Processing Record 42 of Set 12 | puntarenas
# Processing Record 43 of Set 12 | teknaf
# Processing Record 44 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 12 | jieshi
# Processing Record 46 of Set 12 | henties bay
# Processing Record 47 of Set 12 | thunder bay
# Processing Record 48 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 12 | claveria
# Processing Record 50 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 1 of Set 13 | shrewsbury
# Processing Record 2 of Set 13 | fitchburg
# Processing Record 3 of Set 13 | nioaque
# Processing Record 4 of Set 13 | weiser
# Processing Record 5 of Set 13 | port hedland
# Processing Record 6 of Set 13 | sanmenxia
# Processing Record 7 of Set 13 | urucara
# Processing Record 8 of Set 13 | tatarsk
# Processing Record 9 of Set 13 | krasnyy kommunar
# Processing Record 10 of Set 13 | santa marta
# Processing Record 11 of Set 13 | matameye
# City not found. Skipping...
# Processing Record 12 of Set 13 | miri
# Processing Record 13 of Set 13 | asau
# Processing Record 14 of Set 13 | turukhansk
# Processing Record 15 of Set 13 | conakry
# Processing Record 16 of Set 13 | isangel
# Processing Record 17 of Set 13 | te anau
# Processing Record 18 of Set 13 | cavalcante
# Processing Record 19 of Set 13 | matamoros
# Processing Record 20 of Set 13 | klyuchi
# -----------------------------
# There are 47 cities not found. 573 cities in dataframe.
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create the dataframe from the lists we generated from last cell
cities_dict = {'City': city,
               'Latitude' : lat,
               'Longitude' : lon,
               'Max Temperature (°C)': max_temp,
               'Humidity (%)': humidity,
               'Cloudiness (%)': cloudiness,
               'Wind Speed (MPH)': wind_speed,
               'Country': country,
               'Date': date
              }
cities_df = pd.DataFrame(cities_dict)

# Save the dataframe to a csv file
csv_path = 'output_data/cities.csv'
cities_df.to_csv(csv_path)

# Display the dataframe
cities_df
# Out:
#                City  Latitude  Longitude  Max Temperature (°C)  Humidity (%)  \
# 0       provideniya   64.3833  -173.3000                -23.30            87
# 1             kapaa   22.0752  -159.3190                 20.56            63
# 2        sao filipe   14.8961   -24.4956                 22.26            77
# 3           bubaque   11.2833   -15.8333                 25.38            66
# 4    saint-philippe  -21.3585    55.7679                 26.00            73
# ..              ...       ...        ...                   ...           ...
# 568         isangel  -19.5500   169.2667                 27.00            78
# 569         te anau  -45.4167   167.7167                 15.09            72
# 570      cavalcante  -13.7975   -47.4583                 25.02            79
# 571       matamoros   25.5333  -103.2500                 30.00             6
# 572         klyuchi   52.2667    79.1667                 -5.83            98
#
#      Cloudiness (%)  Wind Speed (MPH) Country        Date
# 0               100             12.53      RU  1612473233
# 1                40              6.17      US  1612473236
# 2               100              4.85      CV  1612473181
# 3                35              7.50      GW  1612473343
# 4                20              2.06      RE  1612473345
# ..              ...               ...     ...         ...
# 568              40              3.09      VU  1612474026
# 569              77              0.37      NZ  1612474027
# 570              56              1.20      BR  1612474028
# 571              20              1.15      MX  1612474030
# 572             100              2.33      RU  1612474031
#
# [573 rows x 9 columns]

# %%
# Show a statistics on the dataframe
cities_df.describe()
# Out:
#          Latitude   Longitude  Max Temperature (°C)  Humidity (%)  \
# count  573.000000  573.000000            573.000000    573.000000
# mean    18.948793   14.734531             10.750436     71.551483
# std     33.461382   89.777883             17.854379     20.430495
# min    -54.800000 -175.200000            -41.620000      6.000000
# 25%     -9.800000  -65.102300              1.620000     62.000000
# 50%     21.426700   20.226300             17.000000     75.000000
# 75%     46.538900   92.305800             25.210000     86.000000
# max     78.218600  179.316700             37.120000    100.000000
#
#        Cloudiness (%)  Wind Speed (MPH)          Date
# count      573.000000        573.000000  5.730000e+02
# mean        49.883072          3.689913  1.612474e+09
# std         39.195564          2.657272  2.271251e+02
# min          0.000000          0.180000  1.612473e+09
# 25%          7.000000          1.810000  1.612473e+09
# 50%         43.000000          3.090000  1.612474e+09
# 75%         90.000000          5.080000  1.612474e+09
# max        100.000000         18.030000  1.612474e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Drop any row which has a humidity higher than 100%
cleaned_cities_df = cities_df.loc[cities_df['Humidity (%)'] <= 100]
cleaned_cities_df
# Out:
#                City  Latitude  Longitude  Max Temperature (°C)  Humidity (%)  \
# 0       provideniya   64.3833  -173.3000                -23.30            87
# 1             kapaa   22.0752  -159.3190                 20.56            63
# 2        sao filipe   14.8961   -24.4956                 22.26            77
# 3           bubaque   11.2833   -15.8333                 25.38            66
# 4    saint-philippe  -21.3585    55.7679                 26.00            73
# ..              ...       ...        ...                   ...           ...
# 568         isangel  -19.5500   169.2667                 27.00            78
# 569         te anau  -45.4167   167.7167                 15.09            72
# 570      cavalcante  -13.7975   -47.4583                 25.02            79
# 571       matamoros   25.5333  -103.2500                 30.00             6
# 572         klyuchi   52.2667    79.1667                 -5.83            98
#
#      Cloudiness (%)  Wind Speed (MPH) Country        Date
# 0               100             12.53      RU  1612473233
# 1                40              6.17      US  1612473236
# 2               100              4.85      CV  1612473181
# 3                35              7.50      GW  1612473343
# 4                20              2.06      RE  1612473345
# ..              ...               ...     ...         ...
# 568              40              3.09      VU  1612474026
# 569              77              0.37      NZ  1612474027
# 570              56              1.20      BR  1612474028
# 571              20              1.15      MX  1612474030
# 572             100              2.33      RU  1612474031
#
# [573 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plot the scatter plot that shows the relation between latitude and max temperature, and include the date in title
cleaned_cities_df.plot(kind='scatter', x='Latitude', y='Max Temperature (°C)', 
                       title=f'Latitude vs. Max Temperature ({today})')
plt.grid()
plt.savefig('output_data/Latitude_MaxTemperature_Plot.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plot the scatter plot that shows the relation between latitude and humidity, and include the date in title
cleaned_cities_df.plot(kind='scatter', x='Latitude', y='Humidity (%)', 
                       title=f'Latitude vs. Humidity ({today})')
plt.grid()
plt.savefig('output_data/Latitude_Humidity_Plot.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plot the scatter plot that shows the relation between latitude and cloudiness, and include the date in title
cleaned_cities_df.plot(kind='scatter', x='Latitude', y='Cloudiness (%)', 
                       title=f'Latitude vs. Cloudiness ({today})')
plt.grid()
plt.savefig('output_data/Latitude_Cloudiness_Plot.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plot the scatter plot that shows the relation between latitude and wind speed, and include the date in title
cleaned_cities_df.plot(kind='scatter', x='Latitude', y='Wind Speed (MPH)', 
                       title=f'Latitude vs. Wind Speed ({today})')
plt.grid()
plt.savefig('output_data/Latitude_WindSpeed_Plot.png')

# %% [markdown]
# ## Linear Regression

# %%
# Split the dataframe into two based on the latitude
north_cities_df = cleaned_cities_df.loc[cleaned_cities_df['Latitude'] >= 0]
south_cities_df = cleaned_cities_df.loc[cleaned_cities_df['Latitude'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the linear regression model between latitude and max temperature in the northern hemisphere
north_cities_df.plot(kind='scatter', x='Latitude', y='Max Temperature (°C)', title='Latitude vs. Max Temperature')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_df['Latitude'], north_cities_df['Max Temperature (°C)'])
regress_values = north_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_cities_df['Latitude'], north_cities_df['Max Temperature (°C)'])
plt.plot(north_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq, (49, 35),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-squared is 0.7541036142224002
# The linear regression model is y = -0.78x + 34.3

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the linear regression model between latitude and max temperature in the southern hemisphere
south_cities_df.plot(kind='scatter', x='Latitude', y='Max Temperature (°C)', title='Latitude vs. Max Temperature')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_df['Latitude'], south_cities_df['Max Temperature (°C)'])
regress_values = south_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_cities_df['Latitude'], south_cities_df['Max Temperature (°C)'])
plt.plot(south_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(-22,34),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-squared is 0.18066248749944902
# The linear regression model is y = 0.16x + 27.43

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot the linear regression model between latitude and humidity in the northern hemisphere
north_cities_df.plot(kind='scatter', x='Latitude', y='Humidity (%)', title='Latitude vs. Humidity')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_df['Latitude'], north_cities_df['Humidity (%)'])
regress_values = north_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_cities_df['Latitude'], north_cities_df['Humidity (%)'])
plt.plot(north_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(46,13),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-squared is 0.08345829179116686
# The linear regression model is y = 0.3x + 60.19

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot the linear regression model between latitude and humidity in the southern hemisphere
south_cities_df.plot(kind='scatter', x='Latitude', y='Humidity (%)', title='Latitude vs. Humidity')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_df['Latitude'], south_cities_df['Humidity (%)'])
regress_values = south_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_cities_df['Latitude'], south_cities_df['Humidity (%)'])
plt.plot(south_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(-22,16),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-squared is 0.14734032791604926
# The linear regression model is y = 0.55x + 83.51

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot the linear regression model between latitude and cloudiness in the northern hemisphere
north_cities_df.plot(kind='scatter', x='Latitude', y='Cloudiness (%)', title='Latitude vs. Cloudiness')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_df['Latitude'], north_cities_df['Cloudiness (%)'])
regress_values = north_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_cities_df['Latitude'], north_cities_df['Cloudiness (%)'])
plt.plot(north_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-squared is 0.08652652053932548
# The linear regression model is y = 0.58x + 27.69

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot the linear regression model between latitude and cloudiness in the southern hemisphere
south_cities_df.plot(kind='scatter', x='Latitude', y='Cloudiness (%)', title='Latitude vs. Cloudiness')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_df['Latitude'], south_cities_df['Cloudiness (%)'])
regress_values = south_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_cities_df['Latitude'], south_cities_df['Cloudiness (%)'])
plt.plot(south_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(-56,60),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-squared is 0.1362388283465815
# The linear regression model is y = 1.06x + 73.54

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot the linear regression model between latitude and wind speed in the northern hemisphere
north_cities_df.plot(kind='scatter', x='Latitude', y='Wind Speed (MPH)', title='Latitude vs. Wind Speed')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_cities_df['Latitude'], north_cities_df['Wind Speed (MPH)'])
regress_values = north_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_cities_df['Latitude'], north_cities_df['Wind Speed (MPH)'])
plt.plot(north_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(0,15),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-squared is 0.004843557486699618
# The linear regression model is y = 0.01x + 3.32

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot the linear regression model between latitude and wind speed in the southern hemisphere
south_cities_df.plot(kind='scatter', x='Latitude', y='Wind Speed (MPH)', title='Latitude vs. Wind Speed')

# Find the linear regression model and print it to the scatter plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_cities_df['Latitude'], south_cities_df['Wind Speed (MPH)'])
regress_values = south_cities_df['Latitude'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_cities_df['Latitude'], south_cities_df['Wind Speed (MPH)'])
plt.plot(south_cities_df['Latitude'],regress_values,"r-")
plt.annotate(line_eq,(-22,16),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {line_eq}')
# Out:
# The r-squared is 0.10734770821678735
# The linear regression model is y = -0.07x + 2.2
